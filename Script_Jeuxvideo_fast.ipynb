# %% [markdown]
# <a href="https://colab.research.google.com/github/cindysotton/Video-Game-Prediction/blob/main/Script_Jeuxvideo_fast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup as bs
import requests

# %%
url_jv = 'https://www.jeuxvideo.com/jeux/jeu-1289839/'

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3"}
webpage = Request(url=url_jv, headers=headers)

# %%
page_jv = urlopen(webpage).read()
print(page_jv)
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="fr">\n<head>\n<title>Hogwarts Legacy : l&#039;H\xc3\xa9ritage de Poudlard - jeuxvideo.com</title>\n<meta charset="utf-8">\n<meta name="viewport" id="meta-viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta content="#FFFFFF" name="theme-color" id="meta-theme-color" />\n    <meta name="Googlebot-News" content="noindex, follow">\n    <meta property="fb:app_id" content="202446416762">\n    <meta name="twitter:site" content="@JVCom">\n    <meta name="twitter:card" content="summary">\n        <meta name="keywords" content="" />\n    <meta name="description" content="Hogwarts Legacy : l&#039;H\xc3\xa9ritage de Poudlard : retrouvez toutes les informations et actualit\xc3\xa9s du jeu sur tous ses supports. Hogwarts Legacy : l&#039;H\xc3\xa9ritage de Poudlard est un jeu de r\xc3\xb4le se d\xc3\xa9roulant au XIXe si\xc3\xa8cle dans l&#03
# ...

# %%
gname = []
notes = []
publisher = []
genre = []
themes = []

# %%
soup = bs(page_jv, "html.parser")
soup.prettify().splitlines()[0:30]
# Out:
# ['<!DOCTYPE html>',
#  '<html lang="fr">',
#  ' <head>',
#  '  <title>',
#  "   Hogwarts Legacy : l'Héritage de Poudlard - jeuxvideo.com",
#  '  </title>',
#  '  <meta charset="utf-8"/>',
#  '  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" id="meta-viewport" name="viewport"/>',
#  '  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>',
#  '  <meta content="#FFFFFF" id="meta-theme-color" name="theme-color">',
#  '   <meta content="noindex, follow" name="Googlebot-News"/>',
#  '   <meta content="202446416762" property="fb:app_id"/>',
#  '   <meta content="@JVCom" name="twitter:site"/>',
#  '   <meta content="summary" name="twitter:card"/>',
#  '   <meta content="" name="keywords">',
# ...

# %%
def get_info(link):
    page = requests.get(link)
    soup = bs(page.text, "lxml")
    try : 
      if soup.find('h1', attrs = {'class' : "breadcrumb__item"}).text :
        gname = soup.find('h1', attrs = {'class' : "breadcrumb__item"}).text
    except : 
        gname = "np.nan"    
    try : 
      if soup.find('div', string="Editeur(s) / Développeur(s)").find_next_sibling("div").text :
        editeur_studio = soup.find('div', string="Editeur(s) / Développeur(s)").find_next_sibling("div").text.strip()
    except : 
        editeur_studio = "np.nan"
    try : 
      if soup.find('div', string="Genre(s)").find_next_sibling("div").text :
        genre = soup.find('div', string="Genre(s)").find_next_sibling("div").text.strip()
    except : 
        genre = "np.nan"   
    try : 
      if soup.find('div', string="Thème(s)").find_next_sibling("div").text :
        themes = soup.find('div', string="Thème(s)").find_next_sibling("div").text.strip()
    except : 
        themes = "np.nan"          
    try : 
      if soup.find('div', attrs = {'class' : "userOpinionsPerPlatform"}).text :
        notes = soup.find('div', attrs = {'class' : "userOpinionsPerPlatform"}).text.strip()
    except : 
        notes = "np.nan" 

    line = [gname,editeur_studio,genre,themes,notes]
    return line

get_info('https://www.jeuxvideo.com/jeux/jeu-1289839/')
# Out:
# ["Hogwarts Legacy : l'Héritage de Poudlard",
#  'Warner Bros Games\n                                     \n                                        Avalanche Software',
#  'Action RPG\n                                     \n                                        Aventure\n                                    \n\n                                        Action',
#  'Monstres\n                                     \n                                    Fantasy',
#  'PC(74 avis) \n\n14/20     \n                         \n\n\n\nPS5(208 avis) \n\n16/20     \n                         \n\n\n\nXbox Series(44 avis) \n\n16/20']

# %%
genre_list = []
genre_indice_list = []
genre_indice_list_mano = ['2000','2010','2020','2030','2040','2050','2070','2080','2090','2100','2110','2120','2130','2140','2150','2160','2170','2180','2190','2200','2210','2220','2230','2240','2250','2260','2270','2280','2290','2300','2310','2320','2330','2340','2350','2360','2370','2380','2390','2400','2410','2420','2430','2440','2450','2460','2470','2480','2490','2500','2510','2520','2530','2540','2550','2560','2570','2580','2590','2600','2610','2620']
for i in range (2000,3000):
    all_jeu = "https://www.jeuxvideo.com/tous-les-jeux/genre-"+str(i)+'/'
    page = requests.get(all_jeu)
    soup = bs(page.text,'html5lib')
    error = soup.find('h1', string="Vous êtes sur une page qui n'existe plus ou n'a jamais existé.")
    if error is None:
      genre_list.append(all_jeu)
      genre_indice_list.append(str(i))

# %%
genre_indice_list_mano = ['2000','2010','2020','2030','2040','2050','2070','2080','2090','2100','2110','2120','2130','2140','2150','2160','2170','2180','2190','2200','2210','2220','2230','2240','2250','2260','2270','2280','2290','2300','2310','2320','2330','2340','2350','2360','2370','2380','2390','2400','2410','2420','2430','2440','2450','2460','2470','2480','2490','2500','2510','2520','2530','2540','2550','2560','2570','2580','2590','2600','2610','2620']

# %%
len(genre_indice_list_mano)
# Out:
# 62

# %%
genre_indice_list_mano_1 = ['2000','2010','2020','2030','2040','2050','2070','2080','2090']

# %%
genre_indice_list_mano_2 = ['2100','2110','2120','2130','2140','2150','2160','2170','2180','2190','2200','2210','2220','2230','2240','2250','2260','2270','2280','2290','2300','2310','2320','2330','2340','2350','2360','2370','2380','2390','2400','2410','2420','2430','2440','2450','2460','2470','2480','2490','2500','2510','2520','2530','2540','2550','2560','2570','2580','2590','2600','2610','2620']

# %%
jeu_links = []
for genre in genre_indice_list_mano:
    for i in range(1,2):
      all_jeu = "https://www.jeuxvideo.com/tous-les-jeux/genre-"+genre+'/?p='+str(i)
      jeu_links.append({"name": genre, "link": all_jeu})

print(jeu_links)
# Out:
# [{'name': '2000', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2000/?p=1'}, {'name': '2010', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2010/?p=1'}, {'name': '2020', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2020/?p=1'}, {'name': '2030', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2030/?p=1'}, {'name': '2040', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2040/?p=1'}, {'name': '2050', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2050/?p=1'}, {'name': '2070', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2070/?p=1'}, {'name': '2080', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2080/?p=1'}, {'name': '2090', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2090/?p=1'}, {'name': '2100', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2100/?p=1'}, {'name': '2110', 'link': 'https://www.jeuxvideo.com/tous-les-jeux/genre-2110/?p=1'}, {'name': '2120', 'link': 'https://www.jeuxvideo.com/tous-les-j
# ...

# %%
jeu_link_mano = [{'name': '2000', 'pagef': '595'},
                 {'name': '2010', 'pagef': '37'},
                 {'name': '2020', 'pagef': '86'},
                 {'name': '2030', 'pagef': '8'},
                 {'name': '2040', 'pagef': '64'},
                 {'name': '2050', 'pagef': '34'},
                 {'name': '2070', 'pagef': '15'},
                 {'name': '2080', 'pagef': '164'},
                 {'name': '2090', 'pagef': '35'},
                 {'name': '2100', 'pagef': '344'},
                 {'name': '2110', 'pagef': '4'},
                 {'name': '2120', 'pagef': '39'},
                 {'name': '2130', 'pagef': '15'},
                 {'name': '2140', 'pagef': '108'},
                 {'name': '2150', 'pagef': '6'},
                 {'name': '2160', 'pagef': '5'},
                 {'name': '2170', 'pagef': '57'},
                 {'name': '2180', 'pagef': '2'},
                 {'name': '2190', 'pagef': '10'},
                 {'name': '2200', 'pagef': '206'},
                 {'name': '2210', 'pagef': '99'},
                 {'name': '2220', 'pagef': '2'},
                 {'name': '2230', 'pagef': '7'},
                 {'name': '2240', 'pagef': '266'},
                 {'name': '2250', 'pagef': '17'},
                 {'name': '2260', 'pagef': '5'},
                 {'name': '2270', 'pagef': '7'},
                 {'name': '2280', 'pagef': '13'},
                 {'name': '2290', 'pagef': '8'},
                 {'name': '2300', 'pagef': '37'},
                 {'name': '2310', 'pagef': '1'},
                 {'name': '2320', 'pagef': '1'},
                 {'name': '2330', 'pagef': '212'},
                 {'name': '2340', 'pagef': '16'},
                 {'name': '2350', 'pagef': '3'},
                 {'name': '2360', 'pagef': '4'},
                 {'name': '2370', 'pagef': '32'},
                 {'name': '2380', 'pagef': '6'},
                 {'name': '2390', 'pagef': '39'},
                 {'name': '2400', 'pagef': '9'},
                 {'name': '2410', 'pagef': '7'},
                 {'name': '2420', 'pagef': '2'},
                 {'name': '2430', 'pagef': '7'},
                 {'name': '2440', 'pagef': '147'},
                 {'name': '2450', 'pagef': '25'},
                 {'name': '2460', 'pagef': '15'},
                 {'name': '2470', 'pagef': '22'},
                 {'name': '2480', 'pagef': '3'},
                 {'name': '2490', 'pagef': '6'},
                 {'name': '2500', 'pagef': '35'},
                 {'name': '2510', 'pagef': '8'},
                 {'name': '2520', 'pagef': '7'},
                 {'name': '2530', 'pagef': '1'},
                 {'name': '2540', 'pagef': '128'},
                 {'name': '2550', 'pagef': '4'},
                 {'name': '2560', 'pagef': '170'},
                 {'name': '2570', 'pagef': '68'},
                 {'name': '2580', 'pagef': '126'},
                 {'name': '2590', 'pagef': '3'},
                 {'name': '2600', 'pagef': '3'},
                 {'name': '2610', 'pagef': '11'},
                 {'name': '2620', 'pagef': '201'}]

# %%
jeu_link_mano_2250 = [
                 {'name': '2250', 'pagef': '17'},
                 {'name': '2260', 'pagef': '5'},
                 {'name': '2270', 'pagef': '7'},
                 {'name': '2280', 'pagef': '13'},
                 {'name': '2290', 'pagef': '8'},
                 {'name': '2300', 'pagef': '37'},
                 {'name': '2310', 'pagef': '1'},
                 {'name': '2320', 'pagef': '1'},
                 {'name': '2330', 'pagef': '212'},
                 {'name': '2340', 'pagef': '16'},
                 {'name': '2350', 'pagef': '3'},
                 {'name': '2360', 'pagef': '4'},
                 {'name': '2370', 'pagef': '32'},
                 {'name': '2380', 'pagef': '6'},
                 {'name': '2390', 'pagef': '39'},
                 {'name': '2400', 'pagef': '9'},
                 {'name': '2410', 'pagef': '7'},
                 {'name': '2420', 'pagef': '2'},
                 {'name': '2430', 'pagef': '7'},
                 {'name': '2440', 'pagef': '147'},
                 {'name': '2450', 'pagef': '25'},
                 {'name': '2460', 'pagef': '15'},
                 {'name': '2470', 'pagef': '22'},
                 {'name': '2480', 'pagef': '3'},
                 {'name': '2490', 'pagef': '6'},
                 {'name': '2500', 'pagef': '35'},
                 {'name': '2510', 'pagef': '8'},
                 {'name': '2520', 'pagef': '7'},
                 {'name': '2530', 'pagef': '1'},
                 {'name': '2540', 'pagef': '128'},
                 {'name': '2550', 'pagef': '4'},
                 {'name': '2560', 'pagef': '170'},
                 {'name': '2570', 'pagef': '68'},
                 {'name': '2580', 'pagef': '126'},
                 {'name': '2590', 'pagef': '3'},
                 {'name': '2600', 'pagef': '3'},
                 {'name': '2610', 'pagef': '11'},
                 {'name': '2620', 'pagef': '201'}]

# %%
jeu_list = []

# %%
for genre in jeu_link_mano_2250 :
    print("Genre :" + genre['name'])
    for i in range(1,int(genre["pagef"])+1):
      all_jeu = "https://www.jeuxvideo.com/tous-les-jeux/genre-"+genre['name']+'/?p='+str(i)
      print("URL:" + all_jeu)
      page = requests.get(all_jeu)
      soup = bs(page.text,'lxml')
      a = soup.find_all('span',class_="gameTitleLink__196nPy")
      divs = soup.find_all('div',class_="container__3Ow3zD")
      for div in divs :
        a = div.find("a")
        if ("/jeux/jeu" in a["href"]) and (a["href"] not in jeu_list):
          jeu_list.append(a["href"])
# Out:
# Genre :2250
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=1
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=2
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=3
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=4
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=5
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=6
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=7
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=8
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=9
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=10
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=11
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=12
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=13
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=14
# URL:https://www.jeuxvideo.com/tous-les-jeux/genre-2250/?p=15
# ...

# %%
len(jeu_list)
# Out:
# 9604

# %%
print(jeu_list)
# Out:
# ['/jeux/jeu-1289839/', '/jeux/jeu-1435593/', '/jeux/jeu-1275585/', '/jeux/jeu-1541710/', '/jeux/jeu-1481648/', '/jeux/jeu-1067498/', '/jeux/jeu-1636240/', '/jeux/jeu-1622581/', '/jeux/jeu-1665023/', '/jeux/jeu-1623419/', '/jeux/jeu-1629551/', '/jeux/jeu-1382307/', '/jeux/jeu-1381670/', '/jeux/jeu-1610219/', '/jeux/jeu-1542579/', '/jeux/jeu-1585019/', '/jeux/jeu-1566845/', '/jeux/jeu-1598871/', '/jeux/jeu-1057876/', '/jeux/jeu-1425317/', '/jeux/jeu-1237618/', '/jeux/jeu-1230820/', '/jeux/jeu-1210742/', '/jeux/jeu-1566932/', '/jeux/jeu-1461454/', '/jeux/jeu-1452817/', '/jeux/jeu-1012622/', '/jeux/jeu-1377779/', '/jeux/jeu-1434535/', '/jeux/jeu-1176521/', '/jeux/jeu-1372052/', '/jeux/jeu-1162829/', '/jeux/jeu-1421534/', '/jeux/jeu-1280163/', '/jeux/jeu-1195963/', '/jeux/jeu-1222557/', '/jeux/jeu-1328447/', '/jeux/jeu-1428978/', '/jeux/jeu-1353731/', '/jeux/jeu-1374824/', '/jeux/jeu-1381722/', '/jeux/jeu-1397171/', '/jeux/jeu-1201914/', '/jeux/jeu-1376999/', '/jeux/jeu-1320924/', '/jeux/
# ...

# %%
base = "https://www.jeuxvideo.com"
df = pd.DataFrame(columns = ['Nom','Editeur_Studio','Genres','Thèmes','Notes'])

for index,jeu in enumerate(jeu_list) :
    row = get_info(base+jeu)
    a = pd.DataFrame([row],columns = ['Nom','Editeur_Studio','Genres','Thèmes','Notes'])
    df = pd.concat([df,a],ignore_index=True)
    print(index)

df = df.drop_duplicates().reset_index(drop=True)
df.to_csv("jeuxvideo.csv", sep=",", encoding='utf-8', index=False)
df.head()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 4604
# 4605
# 4606
# 4607
# 4608
# 4609
# 4610
# 4611
# 4612
# 4613
# 4614
# 4615
# 4616
# 4617
# 4618
# 4619
# 4620
# 4621
# 4622
# 4623
# 4624
# 4625
# 4626
# 4627
# 4628
# 4629
# 4630
# 4631
# 4632
# 4633
# 4634
# 4635
# 4636
# 4637
# 4638
# 4639
# 4640
# 4641
# 4642
# 4643
# 4644
# 4645
# 4646
# 4647
# 4648
# 4649
# 4650
# 4651
# 4652
# 4653
# 4654
# 4655
# 4656
# 4657
# 4658
# 4659
# 4660
# 4661
# 4662
# 4663
# 4664
# 4665
# 4666
# 4667
# 4668
# 4669
# 4670
# 4671
# 4672
# 4673
# 4674
# 4675
# 4676
# 4677
# 4678
# 4679
# 4680
# 4681
# 4682
# 4683
# 4684
# 4685
# 4686
# 4687
# 4688
# 4689
# 4690
# 4691
# 4692
# 4693
# 4694
# 4695
# 4696
# 4697
# 4698
# 4699
# 4700
# 4701
# 4702
# 4703
# 4704
# 4705
# 4706
# 4707
# 4708
# 4709
# 4710
# 4711
# 4712
# 4713
# 4714
# 4715
# 4716
# 4717
# 4718
# 4719
# 4720
# 4721
# 4722
# 4723
# 4724
# 4725
# 4726
# 4727
# 4728
# 4729
# 4730
# 4731
# 4732
# 4733
# 4734
# ...
